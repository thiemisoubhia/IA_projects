# %%
import numpy
import cv2
import matplotlib as mpl
from matplotlib import pyplot as plt

# %% [markdown]
# # Desafio Goku

# %%
image_goku = cv2.imread("gokuinvertido.jpg")
image = cv2.cvtColor(image_goku, cv2.COLOR_BGR2RGB)
altura = image.shape[0]
largura = image.shape[1]
print("Altura: {} Largura: {}".format(altura, largura))
plt.imshow(image)
# Out:
# Altura: 720 Largura: 1280

# %%
imagem = cv2.imread("gokuinvertido.jpg")
image = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)
altura = image.shape[0]
largura = image.shape[1]

alt2 = int(image.shape[0]/2)
lar2 = int(image.shape[1]/2)


#crop1 = sup esq
#crop2 = sup dir
#crop3 = inf esq
#crop4 = inf dir

#img[y:y+h, x:x+w]
crop1 = image[0:alt2, 0:lar2]
crop2 = image[0:alt2, lar2:largura]
crop3 = image[alt2:altura, 0:lar2]
crop4 = image[alt2:altura, lar2:largura]

img2 = image.copy()
img2[0:alt2, 0:lar2] = crop4
img2[0:alt2, lar2:largura] = crop3
img2[alt2:altura, 0:lar2] = crop2
img2[alt2:altura, lar2:largura] = crop1
cv2.imwrite("Goku.jpg", cv2.cvtColor(img2, cv2.COLOR_RGB2BGR))
plt.imshow(img2)

# %%
#forçar remover o fundo
imagem = cv2.imread("drone.jpg")
image = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)
print(image.shape)

for y in range (0, image.shape[0]):
  for x in range (0, image.shape[1]):
    if image[y,x,0] > 70:
      image[y,x] = (255, 255, 255)

plt.imshow(image)
# Out:
# (420, 1120, 3)

# %%
imagem = cv2.imread("Capture.png")
image = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

for y in range (0, image.shape[0]):
  for x in range (0, image.shape[1]):
    if image[y,x,0] >= 245:
      image[y,x] =  (255, 128, 249)
    else:
      image[y,x] = 255

plt.imshow(image)
